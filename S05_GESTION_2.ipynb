# %% [markdown]
# <a href="https://colab.research.google.com/github/jarizmendi18-source/repositorio-gestion/blob/main/S05_GESTION_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
dataset_path = "/content/drive/MyDrive/DATOS"

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1200 images belonging to 3 classes.
# Found 299 images belonging to 3 classes.

# %%
base_model = MobileNet(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)
# Out:
# ...
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)

predictions = Dense(
    3,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=predictions
)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 292s 8s/step - accuracy: 0.7894 - loss: 0.5272 - val_accuracy: 0.8345 - val_loss: 0.4000
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9388 - loss: 0.2064 - val_accuracy: 0.8682 - val_loss: 0.3342
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9421 - loss: 0.1614 - val_accuracy: 0.8446 - val_loss: 0.3380
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9681 - loss: 0.1183 - val_accuracy: 0.8682 - val_loss: 0.3029
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9698 - loss: 0.1079 - val_accuracy: 0.8446 - val_loss: 0.3397
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9782 - loss: 0.0838 - val_accuracy: 0.8581 - val_loss: 0.2979
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9857 - loss: 0.0739 - val_accuracy: 0.8615 - val_loss: 0.3185
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(val_generator)

print("Accuracy:", accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8953 - loss: 0.2649
# Accuracy: 0.8952702879905701

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(
    "/content/drive/MyDrive/1.jpg",
    target_size=(224,224)
)

img_array = image.img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)

pred = model.predict(img_array)

labels = ["Pantalon", "Playera", "Sudadera"]

clase = labels[np.argmax(pred)]

print("Clase:", clase)
print("Confianza:", np.max(pred)*100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1285/2857016277.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 img = image.load_img(
#       5     "/content/drive/MyDrive/1.jpg",
#       6     target_size=(224,224)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     245         if isinstance(path, pathlib.Path):
#     246             path = str(path.resolve())
# --> 247         with open(path, "rb") as f:
#     248             img = pil_image.open(io.BytesIO(f.read()))
#     249     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/1.jpg'

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.title(
    f"{clase} ({np.max(pred)*100:.2f}%)"
)
plt.show()
